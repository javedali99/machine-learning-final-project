# %% [markdown]
# # ML Term Project: _"Storm Surge Prediction Using Different Machine Learning Methods"_
#
# **Author:** Javed Ali

# %% [markdown]
# ## Import all required libraries

# %%
# data wrangling and analysis
import pandas as pd 
import numpy as np 
import netCDF4 as nc
from netCDF4 import Dataset

# visualization
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.lines as mlines
import seaborn as sns
import mpl_toolkits
from mpl_toolkits.basemap import Basemap
# %matplotlib inline

# machine learning 
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from keras.models import Sequential
from keras.layers import LSTM
from sklearn.decomposition import PCA
from keras.layers import Dense, Activation
from keras import optimizers
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.experimental import enable_halving_search_cv 
from sklearn.model_selection import HalvingRandomSearchCV
import tensorflow as tf
from sklearn import preprocessing
from keras import regularizers
from keras.layers import Dropout, BatchNormalization
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from statsmodels.tsa.arima_model import ARIMA

# other
import warnings
warnings.filterwarnings("ignore")
import datetime
import time
import math

# %% [markdown]
# ## 1. Data processing (data preprocessing, data cleaning, feature extraction, feature selection)

# %%
# load the data
data_cuxhaven = pd.read_csv("Data/cuxhaven_data.csv")

# rename the columns
data_cuxhaven.columns = ['time', 'wind_u10', 'wind_v10', 'slp', 'weight', 'surge']

# %%
data_cuxhaven.head()
# Out:
#      time  wind_u10  wind_v10            slp    weight     surge
# 0  973008 -2.200400  0.675263  102018.425350  1.000000  0.058339
# 1  973008 -2.815801  2.497101  101985.875446  0.920019  0.058339
# 2  973008 -2.351841  0.509509  102040.607506  0.708661  0.058339
# 3  973008 -3.104915  2.136514  101995.760973  0.657068  0.058339
# 4  973008 -2.731820  0.378651  102067.370760  0.218519  0.058339

# %%
# checking missing values
def missing_percentage(df):
    total = df.isnull().sum().sort_values(ascending = False)
    percent = round(df.isnull().sum().sort_values(ascending = False)/len(df)*100, 2)
    return pd.concat([total, percent], axis=1, keys=['Total','Percent'])

# %%
missing_percentage(data_cuxhaven)
# Out:
#           Total  Percent
# surge       610     2.09
# time          0     0.00
# wind_u10      0     0.00
# wind_v10      0     0.00
# slp           0     0.00
# weight        0     0.00

# %% [markdown]
# ### Data cleaning, feature selection and creating time lagging predictors data

# %%
# build a function for creating time lagged time series data
def time_lag(data, lags):
    """
    Transforms the dataset to  a time series of grid information and spits back the time lagged time series
    data - the full name of the csv file
    """
    time_orig = pd.to_datetime('1900-01-01')

    df = pd.read_csv(data)
    df.columns = ['time', 'wind_u10', 'wind_v10', 'slp', 'weight', 'surge'] 
    
    # reorganize the matrix
    df_new = df.loc[df['weight'] == df['weight'].unique()[0]]
    df_new.drop(['weight'], axis = 1, inplace=True) #, 'surge'
    
    for i in range(1,10):
        df_sub = df.loc[df['weight'] == df['weight'].unique()[i]]
        df_sub.drop(['weight', 'surge'], axis = 1, inplace=True)
        df_new = pd.merge(df_new, df_sub, on='time')
    
    
    # lag the time series data
    lagged_df = df_new.copy() # to prevent modifying original matrix
    for j in range(lags):
        #lagged.drop(j, axis = 0, inplace = True)
        lagged_df['time'] = lagged_df['time'] + 6
        
        # remove the last row since there is no match for it in df_new
        lagged_df.drop(lagged_df.tail(1).index.item(), axis = 0, inplace = True)
        
        # remove the topmost row from df_new to match lagged
        df_new.drop(df_new.head(1).index.item(), axis = 0, inplace = True)
        
        # merge lagged data with df_new
        df_new = pd.merge(df_new, lagged_df, on = 'time', how = 'outer', \
                       suffixes = ('_left', '_right'))
    df_new = df_new.T.reset_index(drop=True).T
    ind = df_new.loc[pd.isna(df_new[df_new.shape[1]-1]), :].index
    df_new.drop(ind, inplace=True)
    
    # storm surge time series data
    surge_ts = pd.DataFrame(df.loc[df['weight'] == \
                                df['weight'].unique()[0]][['time', 'surge']])
    # remove missing/NaN values
    surge_ts.reset_index(inplace=True) # reset index for subsetting isnans
    surge_ts.drop(['index'], axis = 1, inplace=True)    
    indx = surge_ts.loc[pd.isna(surge_ts["surge"]), :].index
    df_new.drop(indx, inplace=True)
    surge_ts.drop(indx, inplace=True)
    
    # filter surge according to df_new
    lagged_time = list(df_new[0])
    time_df_new = [float(x) for x in df_new[0]]
    time_surge_ts = [float(x) for x in surge_ts['time']]
    time_both = []
    for k in lagged_time:
        if ((k in time_df_new) & (k in time_surge_ts)):
            time_both.append(int(k))
            
    surge_ts = surge_ts[surge_ts['time'].isin(time_both)]
    
    dt = pd.DataFrame(columns = ['date']);
    for i in surge_ts.index:
        dt.loc[i, 'date'] = time_orig + \
            datetime.timedelta(hours = int(surge_ts.loc[i, 'time']))
            
    surge_ts['date'] = dt
    df_new = df_new[df_new[0].isin([x*1.0 for x in time_both])]
    df_new.drop(4, axis = 1, inplace = True) # remove the un-lagged surge data
    return df_new, surge_ts

# %% [markdown]
# ### Data preparation (predictor and predictand data)

# %%
data = 'Data/cuxhaven_data.csv'
x, surge = time_lag(data, 5)

# %%
print(x)
# Out:
#            0         1         2              3         5         6    \
# 0     973038.0 -0.639182  3.001633  102051.457474 -0.898009  5.700222
# 1     973044.0 -1.838319  2.502917  102032.409753 -3.133827  4.971777
# 2     973050.0  2.341449  3.430557  102082.560715  1.085867  4.212799
# 3     973056.0  2.145953  1.112911  102064.959656  2.856348  0.480429
# 4     973062.0  0.900008 -2.872451  102044.947493 -0.523537 -6.116284
# ...        ...       ...       ...            ...       ...       ...
# 2914  990522.0 -2.065480 -3.691043  102707.277747 -3.100785 -5.835665
# 2915  990528.0 -2.461980 -1.536243  102691.364461 -6.484800 -2.692158
# 2916  990534.0 -2.515672 -1.377759  102722.467702 -6.561897 -1.370489
# 2917  990540.0 -2.234818 -0.817976  102628.675759 -6.132356 -0.060452
# 2918  990546.0 -2.993400  2.252832  102473.882885 -3.628074  2.518911
#
#                 7         8         9              10   ...            177  \
# 0     102020.595343  0.050562  3.482901  102028.310876  ...  101973.337706
# 1     101972.855485 -1.297262  3.242994  102005.405388  ...  101971.649933
# 2     102102.331767  3.386391  3.600673  102080.872942  ...  101914.747880
# 3     102078.702948  2.742079 -0.073538  102064.477435  ...  101938.858919
# 4     102068.576312  0.831171 -3.484578  102090.517358  ...  101916.676763
# ...             ...       ...       ...            ...  ...            ...
# 2914  102732.353229 -1.827305 -3.467130  102758.393151  ...  101423.364895
# 2915  102666.530091 -2.203154 -1.537697  102741.756534  ...  101593.347724
# 2916  102708.483299 -2.357348 -1.053521  102799.864139  ...  101858.328048
# 2917  102613.485804 -2.240325 -0.618781  102684.131150  ...  102220.475860
# 2918  102493.171717 -2.525310  1.925687  102507.638341  ...  102476.776210
#
#            178        179            180       181       182            183  \
# 0    -4.013560   4.180812  101950.432218 -2.799280  0.416454  102101.608436
# 1    -5.142483   5.282929  101931.143387 -2.156345  1.560737  102134.881670
# 2    -5.907948   7.081504  101867.731353 -2.179749  2.188857  102060.619669
# 3    -3.614307   6.838689  101860.498041 -0.401007  5.012489  101980.088797
# 4    -1.725426   4.471608  101941.993354 -0.937934  3.106319  101929.696724
# ...        ...        ...            ...       ...       ...            ...
# 2914  9.907986   3.462545  101340.905140  3.614929  6.073895  101302.568588
# 2915  5.659381  -6.677520  101648.803114  5.847994 -0.226206  101406.728278
# 2916  7.239873  -9.041694  101935.483374  4.526328 -1.476629  101696.784083
# 2917  2.626434 -12.374219  102333.556636  2.675996 -4.038544  102239.523582
# 2918 -2.607914 -10.481135  102584.793667  0.533796 -3.518019  102611.315810
#
#             184        185            186
# 0     -3.937840   4.247695  101959.835524
# 1     -5.280157   5.447229  101941.993354
# 2     -5.836358   7.455177  101884.367970
# 3     -3.268747   7.388294  101865.320249
# 4     -1.459717   5.492303  101937.653367
# ...         ...        ...            ...
# 2914  10.824892  -0.099709  101297.746380
# 2915   6.317461  -6.299485  101654.830874
# 2916   7.796074  -9.149288  101946.092231
# 2917   3.201909 -12.798781  102412.399735
# 2918  -2.274744 -10.281940  102664.118987
#
# [2853 rows x 186 columns]

# %%
print(surge)
# Out:
#         time     surge                 date
# 5     973038  0.093976  2011-01-02 06:00:00
# 6     973044  0.012088  2011-01-02 12:00:00
# 7     973050 -0.019346  2011-01-02 18:00:00
# 8     973056 -0.089624  2011-01-03 00:00:00
# 9     973062 -0.058735  2011-01-03 06:00:00
# ...      ...       ...                  ...
# 2919  990522 -0.415950  2012-12-30 18:00:00
# 2920  990528 -0.268730  2012-12-31 00:00:00
# 2921  990534 -0.219660  2012-12-31 06:00:00
# 2922  990540 -0.133190  2012-12-31 12:00:00
# 2923  990546 -0.096630  2012-12-31 18:00:00
#
# [2853 rows x 3 columns]

# %% [markdown]
# ### Splitting the data into training and testing datasets

# %%
# split the data into training and testing datasets
x_train, x_test, y_train, y_test = train_test_split(x, surge, shuffle=False, test_size=0.30, random_state=42)

# %% [markdown]
# ### Standardizing the training and testing datasets

# %%
x_norm_train = preprocessing.scale(x_train)
x_norm_test = preprocessing.scale(x_test)

# %% [markdown]
# ## 2. Autocorrelation

# %%
# create a function for plotting autocorrelations 

def autcorrplt(data, lag, *args):
    """
    plots the autocorrelation of a pandas series object
    """
    acorr = [];
    for i in range(lag+1):
        acorr.append(data.autocorr(lag = i))
    
    plt.figure(figsize = (8, 6))
    plt.plot(acorr)
    plt.xlabel("Lag (in 6 hrs)", fontsize = 12)
    plt.ylabel("Correlation", fontsize = 12)
    plt.ylim([0, 1])
    plt.xlim([1, lag])
    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.title("Autocorrelation in slp", fontsize = 16, y=1.03)

# %%
autcorrplt(data_cuxhaven['slp'], 50)

# %% [markdown]
# ## 3. Multi-Layer Perceptron (MLP)

# %% [markdown]
# ### MLP Sequential Model (Building a MLP model, Training the model, Model evaluation and Plotting the results)

# %%
# build a function for implementing MLP Sequential Model 

def mlp_seq(x_norm_train, x_norm_test, y_train, y_test):
    """
    Builds mlp, trains and tests it
    """
    # simple model
    model = Sequential()
    model.add(Dropout(0.2, input_shape = (x_norm_train.shape[1],)))
    model.add(Dense(94, activation = 'sigmoid',\
                    input_shape = (x_norm_train.shape[1],)))
    model.add(Dense(94, activation='sigmoid'))
    model.add(BatchNormalization())
    # model.add(Dense(180, activation='relu'))
    model.add(Dense(1))
    
    # training model
    model.compile(loss = 'mean_squared_error', optimizer = 'adagrad', \
                  metrics=['mean_squared_error', 'mean_absolute_error'])
    history = model.fit(x_norm_train, y_train['surge'], epochs = 50, \
              batch_size = 10, verbose = 1, validation_split=0.30)
    
    testPredict = model.predict(x_norm_test)
    
    # prepare the data for plotting
    y = y_test[:]
    y.reset_index(inplace=True)
    y.drop(['index'], axis = 1, inplace=True) 
    
    # model evaluation
    print()
    print("mse = ", mean_squared_error(y_test['surge'], testPredict))
    print("mae = ", mean_absolute_error(y_test['surge'], testPredict))
    print("r2_score = ", r2_score(y_test['surge'], testPredict))

    print()
    
    # plotting 
    sns.set_context('notebook', font_scale= 1.5)
    plt.figure(figsize=(20, 10))
    plt.plot(y_test['date'], y['surge'], color = 'blue')
    plt.plot(y_test['date'],testPredict, color= 'red')
    plt.legend(['Observed Surge', 'Predicted Surge'], fontsize = 14)
    plt.xlabel('Time')
    plt.ylabel('Surge Height (m)')
    plt.title("Observed vs. Predicted Storm Surge Height", fontsize=20, y=1.03)
    plt.savefig("1 mlp observed vs predicted surge height.png", dpi=300)

    fig, ax = plt.subplots(figsize=(12, 8))
    ax.scatter(y_test['surge'], testPredict, c='black')
    line = mlines.Line2D([0, 1], [0, 1], color='red')
    transform = ax.transAxes
    line.set_transform(transform)
    ax.add_line(line)
    plt.show()

    # list all the data in history
    print(history.history.keys())
    
    # summarize history for accuracy
    plt.figure(figsize=(12, 8))
    plt.plot(history.history['mean_squared_error'])
    plt.plot(history.history['val_mean_squared_error'])
    plt.title('MLP Model Accuracy', fontsize=18, y=1.03)
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['train', 'test'], loc='best')
    plt.savefig("2 mlp model accuracy.png", dpi=300)
    plt.show()

    # summarize history for loss
    plt.figure(figsize = (12, 8))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('MLP Model Loss', fontsize=18, y=1.03)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['train', 'test'], loc='best')
    plt.savefig("3 mlp model loss.png", dpi=300)
    plt.show()
    return testPredict

# %%
mlp_seq(x_norm_train, x_norm_test, y_train, y_test)
# Out:
# Epoch 1/50
# 140/140 [==============================] - 0s 3ms/step - loss: 0.2911 - mean_squared_error: 0.2911 - mean_absolute_error: 0.4076 - val_loss: 0.4998 - val_mean_squared_error: 0.4998 - val_mean_absolute_error: 0.6973
# Epoch 2/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.1471 - mean_squared_error: 0.1471 - mean_absolute_error: 0.2998 - val_loss: 0.1262 - val_mean_squared_error: 0.1262 - val_mean_absolute_error: 0.3341
# Epoch 3/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.1049 - mean_squared_error: 0.1049 - mean_absolute_error: 0.2536 - val_loss: 0.0555 - val_mean_squared_error: 0.0555 - val_mean_absolute_error: 0.1978
# Epoch 4/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0869 - mean_squared_error: 0.0869 - mean_absolute_error: 0.2259 - val_loss: 0.0261 - val_mean_squared_error: 0.0261 - val_mean_absolute_error: 0.1207
# Epoch 5/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0833 - mean_squared_error: 0.0833 - mean_absolute_error: 0.2281 - val_loss: 0.0238 - val_mean_squared_error: 0.0238 - val_mean_absolute_error: 0.1154
# Epoch 6/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0628 - mean_squared_error: 0.0628 - mean_absolute_error: 0.1968 - val_loss: 0.0226 - val_mean_squared_error: 0.0226 - val_mean_absolute_error: 0.1138
# Epoch 7/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0631 - mean_squared_error: 0.0631 - mean_absolute_error: 0.1975 - val_loss: 0.0228 - val_mean_squared_error: 0.0228 - val_mean_absolute_error: 0.1156
# Epoch 8/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0546 - mean_squared_error: 0.0546 - mean_absolute_error: 0.1804 - val_loss: 0.0196 - val_mean_squared_error: 0.0196 - val_mean_absolute_error: 0.1095
# Epoch 9/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0560 - mean_squared_error: 0.0560 - mean_absolute_error: 0.1841 - val_loss: 0.0175 - val_mean_squared_error: 0.0175 - val_mean_absolute_error: 0.1014
# Epoch 10/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0533 - mean_squared_error: 0.0533 - mean_absolute_error: 0.1803 - val_loss: 0.0172 - val_mean_squared_error: 0.0172 - val_mean_absolute_error: 0.1021
# Epoch 11/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0503 - mean_squared_error: 0.0503 - mean_absolute_error: 0.1759 - val_loss: 0.0159 - val_mean_squared_error: 0.0159 - val_mean_absolute_error: 0.0962
# Epoch 12/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0498 - mean_squared_error: 0.0498 - mean_absolute_error: 0.1741 - val_loss: 0.0145 - val_mean_squared_error: 0.0145 - val_mean_absolute_error: 0.0919
# Epoch 13/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0423 - mean_squared_error: 0.0423 - mean_absolute_error: 0.1601 - val_loss: 0.0148 - val_mean_squared_error: 0.0148 - val_mean_absolute_error: 0.0910
# Epoch 14/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0443 - mean_squared_error: 0.0443 - mean_absolute_error: 0.1629 - val_loss: 0.0145 - val_mean_squared_error: 0.0145 - val_mean_absolute_error: 0.0927
# Epoch 15/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0403 - mean_squared_error: 0.0403 - mean_absolute_error: 0.1582 - val_loss: 0.0137 - val_mean_squared_error: 0.0137 - val_mean_absolute_error: 0.0885
# Epoch 16/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0428 - mean_squared_error: 0.0428 - mean_absolute_error: 0.1628 - val_loss: 0.0137 - val_mean_squared_error: 0.0137 - val_mean_absolute_error: 0.0912
# Epoch 17/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0392 - mean_squared_error: 0.0392 - mean_absolute_error: 0.1549 - val_loss: 0.0128 - val_mean_squared_error: 0.0128 - val_mean_absolute_error: 0.0875
# Epoch 18/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0397 - mean_squared_error: 0.0397 - mean_absolute_error: 0.1557 - val_loss: 0.0125 - val_mean_squared_error: 0.0125 - val_mean_absolute_error: 0.0872
# Epoch 19/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0389 - mean_squared_error: 0.0389 - mean_absolute_error: 0.1549 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - val_mean_absolute_error: 0.0802
# Epoch 20/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0333 - mean_squared_error: 0.0333 - mean_absolute_error: 0.1409 - val_loss: 0.0115 - val_mean_squared_error: 0.0115 - val_mean_absolute_error: 0.0808
# Epoch 21/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0346 - mean_squared_error: 0.0346 - mean_absolute_error: 0.1472 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - val_mean_absolute_error: 0.0823
# Epoch 22/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0330 - mean_squared_error: 0.0330 - mean_absolute_error: 0.1432 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - val_mean_absolute_error: 0.0832
# Epoch 23/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0346 - mean_squared_error: 0.0346 - mean_absolute_error: 0.1449 - val_loss: 0.0104 - val_mean_squared_error: 0.0104 - val_mean_absolute_error: 0.0791
# Epoch 24/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0349 - mean_squared_error: 0.0349 - mean_absolute_error: 0.1475 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - val_mean_absolute_error: 0.0828
# Epoch 25/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0299 - mean_squared_error: 0.0299 - mean_absolute_error: 0.1342 - val_loss: 0.0107 - val_mean_squared_error: 0.0107 - val_mean_absolute_error: 0.0790
# Epoch 26/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0314 - mean_squared_error: 0.0314 - mean_absolute_error: 0.1401 - val_loss: 0.0122 - val_mean_squared_error: 0.0122 - val_mean_absolute_error: 0.0858
# Epoch 27/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0319 - mean_squared_error: 0.0319 - mean_absolute_error: 0.1422 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - val_mean_absolute_error: 0.0821
# Epoch 28/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0313 - mean_squared_error: 0.0313 - mean_absolute_error: 0.1373 - val_loss: 0.0104 - val_mean_squared_error: 0.0104 - val_mean_absolute_error: 0.0785
# Epoch 29/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0308 - mean_squared_error: 0.0308 - mean_absolute_error: 0.1350 - val_loss: 0.0101 - val_mean_squared_error: 0.0101 - val_mean_absolute_error: 0.0770
# Epoch 30/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0308 - mean_squared_error: 0.0308 - mean_absolute_error: 0.1351 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - val_mean_absolute_error: 0.0755
# Epoch 31/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0281 - mean_squared_error: 0.0281 - mean_absolute_error: 0.1314 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - val_mean_absolute_error: 0.0751
# Epoch 32/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0288 - mean_squared_error: 0.0288 - mean_absolute_error: 0.1326 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - val_mean_absolute_error: 0.0766
# Epoch 33/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0277 - mean_squared_error: 0.0277 - mean_absolute_error: 0.1299 - val_loss: 0.0085 - val_mean_squared_error: 0.0085 - val_mean_absolute_error: 0.0710
# Epoch 34/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0279 - mean_squared_error: 0.0279 - mean_absolute_error: 0.1292 - val_loss: 0.0084 - val_mean_squared_error: 0.0084 - val_mean_absolute_error: 0.0709
# Epoch 35/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0280 - mean_squared_error: 0.0280 - mean_absolute_error: 0.1324 - val_loss: 0.0088 - val_mean_squared_error: 0.0088 - val_mean_absolute_error: 0.0731
# Epoch 36/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0279 - mean_squared_error: 0.0279 - mean_absolute_error: 0.1297 - val_loss: 0.0085 - val_mean_squared_error: 0.0085 - val_mean_absolute_error: 0.0719
# Epoch 37/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0267 - mean_squared_error: 0.0267 - mean_absolute_error: 0.1282 - val_loss: 0.0084 - val_mean_squared_error: 0.0084 - val_mean_absolute_error: 0.0709
# Epoch 38/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0283 - mean_squared_error: 0.0283 - mean_absolute_error: 0.1309 - val_loss: 0.0081 - val_mean_squared_error: 0.0081 - val_mean_absolute_error: 0.0711
# Epoch 39/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0268 - mean_squared_error: 0.0268 - mean_absolute_error: 0.1274 - val_loss: 0.0080 - val_mean_squared_error: 0.0080 - val_mean_absolute_error: 0.0691
# Epoch 40/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0262 - mean_squared_error: 0.0262 - mean_absolute_error: 0.1255 - val_loss: 0.0076 - val_mean_squared_error: 0.0076 - val_mean_absolute_error: 0.0680
# Epoch 41/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0267 - mean_squared_error: 0.0267 - mean_absolute_error: 0.1282 - val_loss: 0.0075 - val_mean_squared_error: 0.0075 - val_mean_absolute_error: 0.0658
# Epoch 42/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0248 - mean_squared_error: 0.0248 - mean_absolute_error: 0.1241 - val_loss: 0.0089 - val_mean_squared_error: 0.0089 - val_mean_absolute_error: 0.0731
# Epoch 43/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0270 - mean_squared_error: 0.0270 - mean_absolute_error: 0.1257 - val_loss: 0.0081 - val_mean_squared_error: 0.0081 - val_mean_absolute_error: 0.0700
# Epoch 44/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0248 - mean_squared_error: 0.0248 - mean_absolute_error: 0.1223 - val_loss: 0.0083 - val_mean_squared_error: 0.0083 - val_mean_absolute_error: 0.0701
# Epoch 45/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0247 - mean_squared_error: 0.0247 - mean_absolute_error: 0.1236 - val_loss: 0.0079 - val_mean_squared_error: 0.0079 - val_mean_absolute_error: 0.0677
# Epoch 46/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0245 - mean_squared_error: 0.0245 - mean_absolute_error: 0.1227 - val_loss: 0.0081 - val_mean_squared_error: 0.0081 - val_mean_absolute_error: 0.0675
# Epoch 47/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0251 - mean_squared_error: 0.0251 - mean_absolute_error: 0.1250 - val_loss: 0.0079 - val_mean_squared_error: 0.0079 - val_mean_absolute_error: 0.0681
# Epoch 48/50
# 140/140 [==============================] - 0s 2ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - mean_absolute_error: 0.1187 - val_loss: 0.0071 - val_mean_squared_error: 0.0071 - val_mean_absolute_error: 0.0655
# Epoch 49/50
# 140/140 [==============================] - 0s 1ms/step - loss: 0.0247 - mean_squared_error: 0.0247 - mean_absolute_error: 0.1201 - val_loss: 0.0078 - val_mean_squared_error: 0.0078 - val_mean_absolute_error: 0.0666
# Epoch 50/50
# 140/140 [==============================] - 0s 3ms/step - loss: 0.0254 - mean_squared_error: 0.0254 - mean_absolute_error: 0.1239 - val_loss: 0.0071 - val_mean_squared_error: 0.0071 - val_mean_absolute_error: 0.0652
#
# mse =  0.007114036443210977
# mae =  0.05769751934897958
# r2_score =  0.47950235501459826
# dict_keys(['loss', 'mean_squared_error', 'mean_absolute_error', 'val_loss', 'val_mean_squared_error', 'val_mean_absolute_error'])
# array([[ 2.43120603e-02],
#        [-3.83630954e-02],
#        [-3.13207135e-02],
#        [ 1.48231769e-02],
#        [-1.37924170e-02],
#        [-8.65576789e-02],
#        [-6.68151453e-02],
#        [ 7.36871138e-02],
#        [ 7.83662274e-02],
#        [ 2.21563987e-02],
#        [ 2.45529022e-02],
#        [ 2.03743596e-02],
#        [-4.16518711e-02],
#        [-6.68120012e-02],
#        [-1.04956821e-01],
#        [-1.33281142e-01],
#        [-1.93731010e-01],
#        [-1.16962545e-01],
#        [-1.05720073e-01],
#        [-1.62691280e-01],
#        [-1.53430894e-01],
#        [-6.56909272e-02],
#        [-1.12605289e-01],
#        [-2.30121940e-01],
#        [-1.08902276e-01],
#        [-5.69531061e-02],
#        [-8.19612518e-02],
#        [-6.68332279e-02],
#        [-7.99453110e-02],
#        [-8.14216956e-02],
#        [-8.90968069e-02],
#        [-4.45709638e-02],
#        [-5.00778481e-02],
#        [-8.25929195e-02],
#        [-9.12656188e-02],
#        [-1.02491662e-01],
#        [-1.21534012e-01],
#        [-9.98726040e-02],
#        [-9.11265239e-02],
#        [-1.59444600e-01],
#        [-8.31419528e-02],
#        [-1.68404616e-02],
#        [-1.05867878e-01],
#        [-1.47764921e-01],
#        [-1.25553414e-01],
#        [-1.10905349e-01],
#        [-7.32224137e-02],
#        [-9.35323536e-02],
#        [-4.50003669e-02],
#        [-2.11816281e-02],
#        [-2.83036940e-02],
#        [ 6.30241446e-03],
#        [-1.06081456e-01],
#        [-8.65679681e-02],
#        [-1.56510528e-02],
#        [ 2.87038591e-02],
#        [ 5.70763536e-02],
#        [ 7.63866901e-02],
#        [ 1.42104132e-02],
#        [-1.11234315e-01],
#        [-1.45628512e-01],
#        [-1.76987603e-01],
#        [-8.26430619e-02],
#        [-1.77192427e-02],
#        [-6.44925311e-02],
#        [-4.15769704e-02],
#        [-8.32924843e-02],
#        [-1.31109050e-02],
#        [-3.98361124e-02],
#        [ 1.37283923e-02],
#        [ 7.03970790e-02],
#        [ 4.75238040e-02],
#        [-2.29796842e-02],
#        [-8.35196078e-02],
#        [-7.38058388e-02],
#        [-1.53692663e-01],
#        [-1.52381629e-01],
#        [-8.36494789e-02],
#        [-6.11473583e-02],
#        [-1.42958155e-02],
#        [-1.20513476e-02],
#        [-1.92303453e-02],
#        [-1.08440079e-01],
#        [ 1.65293477e-02],
#        [-4.37929817e-02],
#        [ 3.38663831e-02],
#        [ 1.30504012e-01],
#        [ 2.03217506e-01],
#        [ 2.74118543e-01],
#        [ 1.43710092e-01],
#        [-8.69005993e-02],
#        [-1.13965273e-01],
#        [-2.56516635e-01],
#        [-2.93050140e-01],
#        [-2.62953699e-01],
#        [-1.77705571e-01],
#        [-1.96213052e-01],
#        [-1.49727121e-01],
#        [-7.37639591e-02],
#        [ 1.85126010e-02],
#        [ 1.06868550e-01],
#        [ 6.03275113e-02],
#        [ 1.33105695e-01],
#        [ 8.47835019e-02],
#        [ 1.32421464e-01],
#        [ 1.75787210e-01],
#        [ 1.83382928e-01],
#        [ 1.31809548e-01],
#        [ 9.48430821e-02],
#        [ 1.52555391e-01],
#        [ 2.40689009e-01],
#        [ 3.18602562e-01],
#        [ 1.58571467e-01],
#        [-1.67211294e-01],
#        [-2.64254481e-01],
#        [-6.45895675e-02],
#        [-8.22234750e-02],
#        [-1.04276920e-02],
#        [-4.60002385e-02],
#        [ 6.15702104e-03],
#        [ 1.21453539e-01],
#        [ 1.93792567e-01],
#        [ 3.00100148e-01],
#        [ 2.44309396e-01],
#        [-7.26868808e-02],
#        [-2.74743080e-01],
#        [-7.09155202e-02],
#        [-4.86213744e-01],
#        [-3.65861982e-01],
#        [-2.20948368e-01],
#        [-1.43522263e-01],
#        [ 1.89689454e-05]], dtype=float32)

# %% [markdown]
# ### MLP Hyperparameter Tuning

# %%
# X_train=np.asarray(X_train).astype(np.int)

# y_train=np.asarray(y_train).astype(np.int)

# %%
# creating a function for MLP hyper parameters tuning

def mlp_tune():
    
    def create_model(layers, activation, optimizer):
        model = Sequential()
        for i, nodes in enumerate(layers):
            if i==0:
                model.add(Dense(nodes, input_dim = x_norm_train.shape[1]))
                model.add(Activation(activation))
            else:
                model.add(Dense(nodes))
                model.add(Activation(activation))
        model.add(Dense(1, activation = 'linear')) # Note: no activation beyond this point
        
        model.compile(optimizer = optimizer, loss='mse')
        # optimizers.Adam(learning_rate = rate, beta_1 = 0.9, \
        #                       beta_2 = 0.999, amsgrad=False)
        return model
    
    model = KerasRegressor(build_fn = create_model, verbose=1)

    # specifying layer architecture
    optimizer = ['adam', 'rmsprop', 'sgd','adagrad', 'adadelta'] 
    layers = [(3,), (10,), (30,), (10, 10), (10, 20), (20, 20), \
              (30, 30), (10, 10, 10), (20, 20, 20), \
                  (30, 30, 30), (10, 20, 30), (20, 20, 30)]
    activations = ['relu', 'tanh', 'sigmoid']
    param_grid = dict(layers=layers, optimizer = optimizer, activation=activations, \
                      batch_size = [10, 50, 100], epochs=[10, 50])
    grid = GridSearchCV(estimator = model, param_grid = param_grid,\
                        scoring='neg_mean_squared_error')
    
    
    grid_result = grid.fit(x_norm_train, y_train)
    
    [grid_result.best_score_, grid_result.best_params_]
    
    testPredict = grid.predict(x_norm_test)
    
    # model evaluation
    print()
    print(mean_squared_error(y_test, testPredict))
    print()
   
    # list all the data in history
    print(history.history.keys())
    
    # summarize history for accuracy
    plt.figure(figsize=(12, 8))
    plt.plot(grid_result.history['mean_squared_error'])
    plt.plot(grid_result.history['val_mean_squared_error'])
    plt.title('MLP Model Accuracy (After Hyperparameter tuning)', fontsize=18, y=1.03)
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['train', 'test'], loc='best')
    plt.savefig("4 mlp model accuracy after tuning.png", dpi=300)
    plt.show()
    
    
    # summarize history for loss
    plt.figure(figsize = (12, 8))
    plt.plot(grid_result.history['loss'])
    plt.plot(grid_result.history['val_loss'])
    plt.title('MLP Model Loss (After Hyperparameter tuning)', fontsize=18, y=1.03)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['train', 'test'], loc='best')
    plt.savefig("5 mlp model loss after tuning.png", dpi=300)
    plt.show()
    
    # prepare data for plotting
    y = y_test[:]
    y.reset_index(inplace=True)
    y.drop(['index'], axis = 1, inplace=True) 
    
    
    # plotting the results
#     %matplotlib qt5
    sns.set_context('notebook', font_scale= 1.5)
    plt.figure(figsize=(20, 10))
    plt.plot(y['surge'])
    plt.plot(testPredict, color= 'red')
    plt.legend(['Observed Surge', 'Predicted Surge'],fontsize = 14)
    plt.ylabel('Surge Height (m)')
    plt.title("Observed vs. Predicted Storm Surge Height", fontsize=20, y=1.03)
    plt.savefig("6 mlp observed vs predicted surge height (after tuning).png", dpi=300)
    plt.show()

# %%
mlp_tune()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\tensorflow\python\data\util\structure.py in normalize_element(element)
#      92       try:
# ---> 93         spec = type_spec_from_value(t, use_fallback=False)
#      94       except TypeError:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\util\structure.py in type_spec_from_value(element, use_fallback)
#     464
# --> 465   raise TypeError("Could not build a TypeSpec for %r with type %s" %
#     466                   (element, type(element).__name__))
#
# TypeError: Could not build a TypeSpec for         time     surge                 date
# 5     973038  0.093976  2011-01-02 06:00:00
# 6     973044  0.012088  2011-01-02 12:00:00
# 7     973050 -0.019346  2011-01-02 18:00:00
# 8     973056 -0.089624  2011-01-03 00:00:00
# 9     973062 -0.058735  2011-01-03 06:00:00
# ...      ...       ...                  ...
# 1997  984990  0.027008  2012-05-14 06:00:00
# 1998  984996 -0.051136  2012-05-14 12:00:00
# 1999  985002  0.048943  2012-05-14 18:00:00
# 2000  985008  0.032278  2012-05-15 00:00:00
# 2001  985014  0.092561  2012-05-15 06:00:00
#
# [1997 rows x 3 columns] with type DataFrame
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-99ee1e18339a> in <module>
# ----> 1 mlp_tune()
#
# <ipython-input-132-ede319da00fa> in mlp_tune()
#      33
#      34
# ---> 35     grid_result = grid.fit(x_norm_train, y_train)
#      36
#      37     [grid_result.best_score_, grid_result.best_params_]
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search_successive_halving.py in fit(self, X, y, groups, **fit_params)
#     211         self._n_samples_orig = _num_samples(X)
#     212
# --> 213         super().fit(X, y=y, groups=None, **fit_params)
#     214
#     215         # Set best_score_: BaseSearchCV does not set it, as refit is a callable
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     878             refit_start_time = time.time()
#     879             if y is not None:
# --> 880                 self.best_estimator_.fit(X, y, **fit_params)
#     881             else:
#     882                 self.best_estimator_.fit(X, **fit_params)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py in fit(self, x, y, **kwargs)
#     164     fit_args.update(kwargs)
#     165
# --> 166     history = self.model.fit(x, y, **fit_args)
#     167
#     168     return history
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1047          training_utils.RespectCompiledTrainableState(self):
#    1048       # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1049       data_handler = data_adapter.DataHandler(
#    1050           x=x,
#    1051           y=y,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1103
#    1104     adapter_cls = select_data_adapter(x, y)
# -> 1105     self._adapter = adapter_cls(
#    1106         x,
#    1107         y,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     362     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     363
# --> 364     dataset = self.slice_inputs(indices_dataset, inputs)
#     365
#     366     if shuffle == "batch":
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in slice_inputs(self, indices_dataset, inputs)
#     388     dataset = dataset_ops.DatasetV2.zip((
#     389         indices_dataset,
# --> 390         dataset_ops.DatasetV2.from_tensors(inputs).repeat()
#     391     ))
#     392
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in from_tensors(tensors)
#     602       Dataset: A `Dataset`.
#     603     """
# --> 604     return TensorDataset(tensors)
#     605
#     606   @staticmethod
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, element)
#    2980   def __init__(self, element):
#    2981     """See `Dataset.from_tensors()` for details."""
# -> 2982     element = structure.normalize_element(element)
#    2983     self._structure = structure.type_spec_from_value(element)
#    2984     self._tensors = structure.to_tensor_list(self._structure, element)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\util\structure.py in normalize_element(element)
#      96         # the value. As a fallback try converting the value to a tensor.
#      97         normalized_components.append(
# ---> 98             ops.convert_to_tensor(t, name="component_%d" % i))
#      99       else:
#     100         if isinstance(spec, sparse_tensor.SparseTensorSpec):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1497
#    1498     if ret is None:
# -> 1499       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1500
#    1501     if ret is NotImplemented:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     336                                          as_ref=False):
#     337   _ = as_ref
# --> 338   return constant(v, dtype=dtype, name=name)
#     339
#     340
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py in constant(value, dtype, shape, name)
#     261     ValueError: if called on a symbolic tensor.
#     262   """
# --> 263   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     264                         allow_broadcast=True)
#     265
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     273       with trace.Trace("tf.constant"):
#     274         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 275     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     276
#     277   g = ops.get_default_graph()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     298 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     299   """Implementation of eager constant."""
# --> 300   t = convert_to_eager_tensor(value, ctx, dtype)
#     301   if shape is None:
#     302     return t
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97   ctx.ensure_initialized()
# ---> 98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#     100
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type int).

# %% [markdown]
# ## 4. Long Short-Term Memory Networks (LSTM)

# %% [markdown]
# ### Building LSTM model, Data preparation, Training the model, Model evaluation and Plotting the results
